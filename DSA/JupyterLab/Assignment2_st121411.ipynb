# %% [markdown]
# # Assignment2 st121411 [Code and Report]
# Graph the functions 1, n, n^2, sqrt(n), n log n, n^3, 2^n using python
#
# Since some values will likely fall off the graph.  Use logarithmic scale for the x and y axes.
#
# The following is just optional and is recommended for a nice graph.  For x, plot from 10^0 to 10^15 with 15 units in between (i.e., 10^0, 10^1....10^14, 10^15).  For y, plot from 10^0 to 10^44 with 12 units in between.
#
# Submit the followings:
# 1. Python code in pdf (exported)
# 2. Your report (please keep them short - like one page) reporting what you learn - **no cover pages needed!**

# %%
import numpy as np
import matplotlib.pyplot as plt

#create x series logarithmic
x = np.logspace(0,15,100,dtype=np.float128)
y_1 = np.ones(100)
y_n = x
y_square = x*x
y_squareroot = np.sqrt(x)
y_nlogn = x*np.log(x)
y_cube = x**3
y_2n = 2**x

#create y series for all the functions
fig = plt.figure()
p = fig.add_subplot(1,1,1)
p.set_yscale('log')
p.set_xscale('log')
p.set_xlim(1,10**15)
p.set_ylim(1,10**19)

p.plot(x,y_1,label='1')
p.plot(x,y_n,label='n')
p.plot(x,y_square,label='n^2')
p.plot(x,y_squareroot,label='sqrt(n)')
p.plot(x,y_nlogn,label='nlogn')
p.plot(x,y_cube,label='n^3')
p.plot(x,y_2n,label='2^n')

p.set_title('Functions')
p.set_xlabel('x')
p.set_ylabel('y')

p.legend()

plt.show()
# Out:
# <ipython-input-19-4f6107498152>:12: RuntimeWarning: overflow encountered in power
#   y_2n = 2**x

# %% [markdown]
# From this assignment, I learnt about how different each of these functions are when subjected to large values. Plotting the graphs gave me a visual understanding of their differences and also allow me to be able to visually see that the smallest to largest functions follows 1 -> sqrt(n) -> n -> nlogn -> n^2 -> n^3 -> 2^n. Interestingly, 2^n gave me errors because the value is too large for floats, thus causing an overflow. Which probably means we should - at all means - avoid using an algorithm with O(2^n).
